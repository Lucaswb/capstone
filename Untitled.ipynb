# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
def resize_main(img, width = 100):
    
    
    
    """resizes image based on the desired width while maintaining the correct aspect ratio.
    the function takes an pixle value for the width and and PIL image file and returns an image with the desired width."""
    basewidth = width
    wpercent = (basewidth/float(img.size[0]))
    hsize = int((float(img.size[1])*float(wpercent)))
    img_new = img.resize((basewidth,hsize), Image.ANTIALIAS)
    return img_new

# %%
def rand_card_loc(back_img, card_img):
    bg_img, cd_img = back_img.copy(), card_img.copy()
    bg_img = resize(bg_img, width = 1500)
    cd_img = resize(cd_img, width = 100)
    # get the dimensions to overlay the cards
    print(bg_img.size)
    print(cd_img.size)
    return

# %%
def rand_card_loc(back_img, card_img):
    """card takes in random image and random background and returns an image superimposed on that background"""
    #resize the fards
    bg_img, cd_img = back_img.copy(), card_img.copy()
    bg_img = resize_main(bg_img, width = 1000)
    cd_img = resize_main(cd_img, width = 150)
    
    # get the dimensions to overlay the cards
    b_width, b_height = bg_img.size
    c_width, c_height = cd_img.size
    
    # rotates the card image
    
    width_random = np.random.randint(0, b_width-c_width)
    height_random = np.random.randint(0, b_height-c_height)
    rotation = np.random.randint(0, 360)
    transperency = np.random.randint(100, 255) # changes the opacity
    persX = np.random.randint(1, 20)
    persY = np.random.randint(1, 20)
    
    #perspective shift
    pts1 = np.float32([[0,0],[c_width,0],[0,c_height],[c_width,c_height]])
    pts2 = np.float32([[persX,persY],[c_width+persX,persY],[persX,c_height+persY],[c_width+persX,c_height+persY]])
    M = cv2.getPerspectiveTransform(pts1,pts2)

    dst = cv2.warpPerspective(img,M,(300,300))
    
    
    mask = Image.new('L', cd_img.size, transperency)
    cd_img = cd_img.rotate(rotation, expand = True)
    mask = mask.rotate(rotation, expand =True)
    
    bg_img.paste(cd_img, (width_random, height_random), mask)
    return bg_img

# %%
card_img = Image.open('images/unaltered_cards/2Diamonds.png')

# %%
card_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=150x229 at 0x7FB8A8FD0E80>

# %%
sun_img_original = Image.open('images/background/sunset.jpg')
sun_image = sun_img_original.copy()
sun_image.size
# Out:
# (960, 502)

# %%
#warp perspective
img = cv2.imread('images/unaltered_cards/2Diamonds.png')

cd_img = card_img.copy()


c_width, c_height = cd_img.size

values = 30

persX1 = np.random.randint(1, values)
persX2 = np.random.randint(1, values)
persX3 = np.random.randint(1, values)
persX4 = np.random.randint(1, values)
persY1 = np.random.randint(1, values)
persY2 = np.random.randint(1, values)
persY3 = np.random.randint(1, values)
persY4 = np.random.randint(1, values)



pts1 = np.float32([[0,0],[c_width,0],[0,c_height],[c_width,c_height]])
pts2 = np.float32([[persX1,persY2],[c_width-persX2,persY2],[persX3,c_height-persY3],[c_width-persX4,c_height-persY4]])

M = cv2.getPerspectiveTransform(pts1,pts2)
dst = cv2.warpPerspective(img,M,(c_width,c_height))

plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
rand_card_loc(sun_image, card_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x522 at 0x7FB8D1024860>
